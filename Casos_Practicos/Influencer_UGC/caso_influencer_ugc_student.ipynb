# %% [markdown]
# # Caso Practico 2: Influencer Marketing + UGC
#
# **Version estudiante (live coding).**
#
# Objetivo: analizar performance de contenido UGC con estadistica, filtros, visualizacion y reporte.

# %% [markdown]
# ## 1) Carga de datos

# %%
import pandas as pd
from pathlib import Path

try:
    import matplotlib.pyplot as plt
    HAS_MPL = True
except ImportError:
    HAS_MPL = False
    plt = None
    print('Aviso: matplotlib no esta instalado. Puedes resolver todo excepto graficas.')

DATA_PATH = Path('datos/campanas_influencer_ugc.csv')
if not DATA_PATH.exists():
    DATA_PATH = Path('Casos_Practicos/Influencer_UGC/datos/campanas_influencer_ugc.csv')

df = pd.read_csv(DATA_PATH, parse_dates=['fecha'])
df.head()

# %% [markdown]
# ## 2) Exploracion inicial

# %%
# TODO: mostrar shape, tipos, nulos y valores unicos de tier/plataforma/tipo_contenido
pass

# %%
assert df.shape[0] >= 180
assert {'costo_total_usd', 'ingresos_usd', 'views', 'conversiones'}.issubset(df.columns)
print('OK carga y estructura')

# %% [markdown]
# ## 3) Metricas derivadas
# Crea columnas: `engagement_total`, `engagement_rate`, `ctr_link`, `cvr`, `cpc`, `cpa`, `roas`, `roi`.

# %%
# TODO
# df['engagement_total'] = ...
# df['engagement_rate'] = ...
# df['ctr_link'] = ...
# df['cvr'] = ...
# df['cpc'] = ...
# df['cpa'] = ...
# df['roas'] = ...
# df['roi'] = ...
pass

# %%
metricas = {'engagement_total', 'engagement_rate', 'ctr_link', 'cvr', 'cpc', 'cpa', 'roas', 'roi'}
if metricas.issubset(df.columns):
    assert df[list(metricas)].isna().sum().sum() == 0
    print('OK metricas derivadas')
else:
    print('Aun faltan metricas')

# %% [markdown]
# ## 4) Filtros de negocio
# Responde:
# - Top 10 campañas por ROAS con costo > mediana
# - ¿Qué `tier` tiene mejor ROI promedio?
# - ¿Qué tipo de contenido gana en engagement_rate y conversiones?

# %%
# TODO
# top_roas = ...
# roi_tier = ...
# contenido_perf = ...
pass

# %% [markdown]
# ## 5) Estadistica descriptiva y segmentacion

# %%
# TODO: resumen global + agregados por plataforma, tier y pais
pass

# %% [markdown]
# ## 6) Outliers (IQR) en ROI o CPA

# %%
# TODO: detectar outliers con IQR
pass

# %% [markdown]
# ## 7) Graficas
# Genera 3:
# 1. Tendencia mensual de costo vs ingresos
# 2. Barras de ROI promedio por tier
# 3. Scatter seguidores vs conversiones (color por plataforma)

# %%
# TODO
# if HAS_MPL:
#     ...
# else:
#     print('Instala matplotlib para graficas')
pass

# %% [markdown]
# ## 8) Reporte en Markdown
# Genera `reporte_caso_influencer_ugc.md` con:
# - Hallazgos
# - 3 insights
# - 2 recomendaciones de asignacion de presupuesto

# %%
# TODO: escribir markdown a archivo
pass
