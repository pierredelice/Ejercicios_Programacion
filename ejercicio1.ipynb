# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# # Titulo

# %% [markdown]
# ## Título

# %% [markdown]
# # Título
# ## Título
# ### Título
# Esto es una pueba
#  1. Escribir
#  2. Contar
#
#  Nuestra fuente es [webatifax](https://github.com/webartifex/intro-to-python) tambien lo pueden consultar

# %% [markdown]
# Esto es una prueba de conocimiento

# %% [markdown]
# This line will break.<br/>This line starts on a new line.

# %%
print(8+10)
# Out:
# 18

# %%
a = 10
b = 8
c = a + b
print(c)
# Out:
# 18

# %%
9*10 + 6 - 12/3
# Out:
# 92.0

# %%
result = 3 + 4
print(result)
# Out:
# 7

# %%
a = 6
b = 7
c = a + b
print("La suma de", a, "y", b, "es", c)
# Out:
# La suma de 6 y 7 es 13

# %%
a < b
# Out:
# True
